# %% [markdown]
# <a href="https://colab.research.google.com/github/tanu100/DeepLearning/blob/main/Notes/Keras_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction Keras
#
# Keras is an open-source undeniable level Neural Network library, which is written in Python is sufficiently skilled to run on Theano, TensorFlow, or CNTK. It was created by one of the Google engineers, Francois Chollet. It is made easy to use, extensible, and measured for working with quicker trial and error with profound neural organizations.
#
# It not just backings Convolutional Networks and Recurrent Networks separately yet in addition their blend.
#
# It can’t deal with low-level calculations, so it utilizes the Backend library to determine it. The backend library go about as a significant level API covering for the low-level API, which allows it to run on TensorFlow, CNTK, or Theano.

# %% [markdown]
# At first, it had more than 4800 supporters during its send off, which currently has gone up to 250,000 engineers.
#
# It has a 2X development since the time consistently it has developed. Enormous organizations like Microsoft, Google, NVIDIA, and Amazon have effectively added to the improvement of Keras.
#
# It has an astonishing industry cooperation, and it is utilized in the improvement of well known firms likes Netflix, Uber, Google, Expedia, and so on Before incessant years when information and processing were so scanty, every information point produced by an association was not saved and no such information driven outcomes were represented in application plan.
#
# However, time changes absolutely, we have now the plenty of processing and capacity resources, the remembering to focus on the information first and developing volume of information is accessible for different business applications.
#
# Immense endeavors are created on a feasible plan of action comprising of income development from significant bits of knowledge, hauled out from information.
#
# Most uplifting increase in the surge of information and the chance of PC power is the means by which we intellectualize complex business issues exclusively.
#
# Different apparatuses and methodologies are in presence for a long time, presently exceptionally executed for tending to confounded business issues (read the article how business experts use procedures for issues), one of them is Deep picking up, having its foundations in customary AI calculations like neural organizations that could be worked on an immense measure of information.

# %% [markdown]
# #Beginning with Keras :-
#
# Keras is a conservative and available to-comprehend regarded Python library for profound discovering that can be executed over TensorFlow (or CNTK or Theano). It was created by a Google engineer named François Chollet.
#
# It allows engineers to focus on the center ideas of profound learning like developing layers for neural organizations while being worried about the bare essential of points of interest of tensors, their shapes, and numerical particulars (tasks).
#
# The principle purpose for utilizing the Keras is tied in with being easy to use, simplicity of profound taking on and model structure, hold a wide scope of creation execution choices, collection with numerous backends supports like TensorFlow, CNTK, Theano, MXNet, and PlaidML and some more, secure establishment to different GPUs and appropriated preparing.
#
# It is additionally embraced by Google, Microsoft, Nvidia, Amazon, Apple, Uber, and others.TensorFlow fills in as a backend for Keras, one can involve Keras for profound learning applications without teaming up with the equivalently intricate TensorFlow (or CNTK or Theano).

# %% [markdown]
# #There are two kinds of the main system;
#
# **Sequential API:** It depends on the idea of succession of layers, this is the most famous and rudimentary piece of Keras. It upholds planning models layer-by-layer for complex issues with the limit that Sequential API doesn’t fabricate models that offer layers or display different information sources and results.
#
# **Functional API:** It can be represented as a direct reserve of layers. It favors planning similar models while giving greater adaptability as far as clarity and openness. It considers different info and result layers alongside shared layers that let to develop complex organization structures. While utilizing a practical API, one requirements to run the past layer to the current layer that needs the execution of the info layer.

# %% [markdown]
# #Keras Principles :-
#
# **1. User-cordiality:** Keras is an API, developed for individuals, not machines. It lays the client experience focus and front. It stresses the best exercise in diminishing mental assignments, for example, it proffers simple and connected with APIs, lessens the activity needed for general use cases and gives clear and noteworthy outcomes over client blunders.
#
#
# **2. Easy Extensibility:** New parts can be added effectively like new gatherings or works, and surprisingly current parts give wide models like recently added parts grant total enunciation that settles on Keras a decent decision for a forward leap.

# %% [markdown]
# **3. Modularity:** A functioning model can be portrayed as a succession or a diagram of deserted, no doubt configurable parts that fuel together for certain limitations. As a general rule, neural organizations, cost capacities, introduction plans, actuation capacities, streamlining agents, regularization plans are solo capacities that cooperate to create new models.
#
#
# **4. Operate with Python:** Possessing the same design models information in a predefined design, models are tended to in Python code just which is minimized, light to troubleshoot, change, and gives straightforwardness to adaptability.

# %% [markdown]
# #Keras layers :-
#
# Keras has a wide assortment of predefined layer types and it likewise upholds thinking of one own layer.
#
# **1. Core Layers:** It comprises thick (spot item + predisposition), Activation work (move work having neuron shape), Dropout (arbitrarily, fix a piece of contributions to zero at a pace of each preparing update to evade overfitting), Lambda (tie a subjective translation as a layer object).
#
# **2. Convolution Layers:** The utilization of channels to plan a component map that executes from 1D to 3D and fuses most variations like trimming and translated convolution layers for each dimensionality. 2D convolution that is spurred by the visual cortex is utilized for picture acknowledgment.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3. Pooling Layers:** They are directed from 1D to 3D that include variations as max and normal pooling. Close by associated layers serve like convolution layers.
#
# **4. Recurrent Layers:** They incorporate straightforward that are completely associated repeat, gated, LSTM and different layers that are gainful for language handling in which Noise Layers help to avoid overfitting.

# %% [markdown]
# #Keras use and Application :-
#
# Keras models are profoundly executed over an immense scope of stages (profound learning structure) incorporates;
#
# 1. In iOS through CoreML
#
# 2. In Android, through TensorFlow Android runtime
#
# 3. In a program through Keras.js and WebDNN
#
# 4. On Google Cloud through TensorFlow-Serving
#
# #Keras use and Application

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Moreover, Keras prepares ten well known models as Keras Applications that are
#
# Xception,
#
# VGG16,
#
# VGG19,
#
# ResNet50,
#
# InceptionV3,
#
# InceptionResNetV2,
#
# MobileNet,
#
# DenseNet,
#
# NASNet, and
#
# MobileNetV2TK

# %% [markdown]
# They can be represented by foreseeing the order of pictures, highlights removing, and tweaking of models for a considerable length of time of gatherings. For instance, tweaking can be sent to accelerate preparing, similar to, one can add one layer, lock the base layer to prepare another layer, then, at that point, open a couple of base layers to calibrate the preparation.

# %% [markdown]
# #What makes Keras exceptional?
# Zero in on client experience has forever been a significant piece of Keras.
# Enormous reception in the business.
#
# It is a multi backend and upholds multi-stage, which assists all the encoders with meeting up for coding.
#
# Research people group present for Keras works incredibly with the creation local area.
#
# Simple to get a handle on all ideas.
#
# It upholds quick prototyping.
#
# It consistently runs on CPU just as GPU.
#
# It gives the opportunity to plan any engineering, which afterward is used as an API for the undertaking.
#
# It is actually quite easy to get everything rolling with.
#
# Simple creation of models really makes Keras extraordinary.

# %% [markdown]
# #Keras client experience :-
#
# 1. Keras is an API intended for people. Best practices are trailed by Keras to diminish mental burden, guarantees that the models are reliable, and the relating APIs are straightforward.
#
# 2. Not intended for machines. Keras gives clear criticism upon the event of any blunder that limits the quantity of client activities for most of the normal use cases.
#
# 3. Easy to learn and utilize.
#
# 4. Highly Flexible
#
# Keras give high adaptability to every one of its designers by coordinating low-level profound learning dialects, for example, TensorFlow or Theano, which guarantees that anything written in the base language can be carried out in Keras.

# %% [markdown]
# #How Keras support the case of being multi-backend and multi-stage?
#
# Keras can be created in R just as Python, to such an extent that the code can be run with TensorFlow, Theano, CNTK, or MXNet according to the prerequisite. Keras can be run on CPU, NVIDIA GPU, AMD GPU, TPU, and so on It guarantees that delivering models with Keras is truly straightforward as it absolutely supports to run with TensorFlow serving, GPU speed increase (WebKeras, Keras.js), Android (TF, TF Lite), iOS (Native CoreML) and Raspberry Pi.

# %% [markdown]
# #Keras with Deep Learning Frameworks :-
#
# Keras doesn’t supplant any of TensorFlow (by Google), CNTK (by Microsoft) or Theano however rather it deals with top of them. Infact, Keras needs any of these backend profound learning motors, yet Keras authoritatively suggests TensorFlow.

# %% [markdown]
# #Highlights of Keras library :-
#
# 1. Keras is an easy to understand API. It has steady and basic APIs. For customary use cases, it requires extremely less of client exertion.
#
# 2. Keras gives an exceptionally valuable criticism about client activities in the event of any blunder. It furnishes with the noteworthy criticism which assists engineers with pinpointing the line or blunder and right it.
#
# 3. Keras doesn’t need separate design records for models. You can depict the model setup in Python code itself.
#
# 4. Keras can run consistently on both CPU and GPU with required libraries introduced.
#
# 5. Keras is extensible, and that implies you can add new modules as new classes and capacities.
#
# 6. When it comes to help for advancement with Keras Library, Keras gives great number of guides to the current models.

# %% [markdown]
# #Multi-input and multi-yield models :-
#
# Since utilitarian API clarifies well multi-input and multi-yield models, it handles an enormous number of entwined datastreams by controlling them. Allow us to check out a model given underneath to see all the more momentarily about its idea. Fundamentally, we will figure the number of retweets and preferences a news feature via online media like twitter will get.
#
# Both the feature, which is a succession of words, and an assistant information will be given to the model that acknowledges information, for instance, at what time or the date the feature got posted, and so forth The two-misfortune capacities are likewise used to supervise the model, to such an extent that assuming we utilize the principle misfortune work in the underlying advances, it would be the most ideal decision for regularizing the profound learning models.

# %% [markdown]
# #Keras Backend :-
#
# Keras being a model-level library helps in growing profound learning models by offering undeniable level structure blocks.Every one of the low-level calculations like results of Tensor, convolutions, and so on are not taken care of by Keras itself, rather they rely upon a particular tensor control library that is very much advanced to fill in as a backend motor.
#
#
# Keras has overseen it so entirely that as opposed to fusing one single library of tensor and performing activities connected with that specific library, it offers stopping of various backend motors into Keras. Keras comprise of three backend motors, which are as per the following:

# %% [markdown]
# #TensorFlow :
#
# TensorFlow is a Google item, which is one of the most well known profound learning instruments broadly utilized in the exploration area of AI and profound neural organization.
# It came into the market on ninth November 2015 under the Apache License 2.0. It is inherent such a way that it can without much of a stretch sudden spike in demand for numerous CPUs and GPUs just as on versatile working frameworks. It comprises of different coverings in particular dialects like Java, C++, or Python.

# %% [markdown]
# #Theano :
#
# Theano was created at the University of Montreal, Quebec, Canada, by the MILA bunch.
#
# It is an open-source python library that is generally utilized for performing numerical procedure on multi-faceted exhibits by fusing scipy and numpy.
#
# It uses GPUs for quicker calculation and productively processes the inclinations by building emblematic diagrams consequently. It has emerged to be truly appropriate for temperamental articulations, as it initially notices them mathematically and afterward registers them with more steady calculations.
#
# #CNTK :
#
# Microsoft Cognitive Toolkit is profound learning’s open-source system.
# It comprises of all the fundamental structure blocks, which are needed to shape a neural organization.
#
# The models are prepared utilizing C++ or Python, however it joins C# or Java to stack the model for making forecasts.

# %% [markdown]
# #Benefits of Keras :-
#
# Keras envelops the accompanying benefits, which are as per the following:
#
# It is exceptionally straightforward and consolidate the quicker arrangement of organization models.
#
# It has enormous local area support in the market as a large portion of the AI organizations are excited about utilizing it.
#
# It upholds multi backend, and that implies you can utilize any of them among TensorFlow, CNTK, and Theano with Keras as a backend as per your necessity.
#
# Since it has a simple arrangement, it likewise holds support for cross-stage. Following are the gadgets on which Keras can be sen

# %% [markdown]
# 1. iOS with CoreML
#
# 2. Android with TensorFlow Android
#
# 3. Web program with .js support
#
# 4. Cloud motor
#
# 5. Raspberry pi

# %% [markdown]
# #Keras Implementation Process
#
# Load Data
#
# Define Keras Model
#
# Compile Keras Model
#
# Fit Keras Model
#
# Evaluate Keras Model
#
# Tie It All Together
#
# Make Predictions

# %%
#load data
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
...
# Out:
# Ellipsis

# %%
# load the dataset
dataset = loadtxt('pima-indians-diabetes.data.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5846 - loss: 0.9296
# Epoch 2/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6237 - loss: 0.7770
# Epoch 3/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6263 - loss: 0.7347
# Epoch 4/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6289 - loss: 0.6860
# Epoch 5/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6315 - loss: 0.7045
# Epoch 6/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6341 - loss: 0.7105
# Epoch 7/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6445 - loss: 0.6709
# Epoch 8/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6432 - loss: 0.6791
# Epoch 9/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6589 - loss: 0.6488
# Epoch 10/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6497 - loss: 0.6642
# Epoch 11/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6628 - loss: 0.6437
# Epoch 12/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6602 - loss: 0.6698
# Epoch 13/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6615 - loss: 0.6276
# Epoch 14/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6810 - loss: 0.6095
# Epoch 15/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6745 - loss: 0.6193
# Epoch 16/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6615 - loss: 0.6533
# Epoch 17/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6680 - loss: 0.6159
# Epoch 18/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6628 - loss: 0.6399
# Epoch 19/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6758 - loss: 0.6066
# Epoch 20/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6823 - loss: 0.6076
# Epoch 21/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.6086
# Epoch 22/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6602 - loss: 0.6444
# Epoch 23/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6849 - loss: 0.6002
# Epoch 24/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6680 - loss: 0.6227
# Epoch 25/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6836 - loss: 0.5973
# Epoch 26/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6641 - loss: 0.6372
# Epoch 27/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.6087
# Epoch 28/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6888 - loss: 0.6004
# Epoch 29/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6693 - loss: 0.6096
# Epoch 30/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6862 - loss: 0.5934
# Epoch 31/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6667 - loss: 0.6223
# Epoch 32/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6901 - loss: 0.5939
# Epoch 33/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6914 - loss: 0.6023
# Epoch 34/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6849 - loss: 0.5903
# Epoch 35/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6667 - loss: 0.6259
# Epoch 36/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6784 - loss: 0.6161
# Epoch 37/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6810 - loss: 0.5940
# Epoch 38/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6823 - loss: 0.5991
# Epoch 39/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6940 - loss: 0.5895
# Epoch 40/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6888 - loss: 0.5837
# Epoch 41/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6823 - loss: 0.5914
# Epoch 42/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6927 - loss: 0.5973
# Epoch 43/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6849 - loss: 0.5958
# Epoch 44/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6992 - loss: 0.5833
# Epoch 45/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6862 - loss: 0.6173
# Epoch 46/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6901 - loss: 0.5878
# Epoch 47/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.5800
# Epoch 48/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6914 - loss: 0.5836
# Epoch 49/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6823 - loss: 0.5962
# Epoch 50/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6797 - loss: 0.5831
# Epoch 51/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6966 - loss: 0.5741
# Epoch 52/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6927 - loss: 0.5754
# Epoch 53/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6810 - loss: 0.5820
# Epoch 54/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6810 - loss: 0.5861
# Epoch 55/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6992 - loss: 0.5776
# Epoch 56/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6706 - loss: 0.5896
# Epoch 57/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6680 - loss: 0.6327
# Epoch 58/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.5946
# Epoch 59/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6771 - loss: 0.6252
# Epoch 60/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6953 - loss: 0.5831
# Epoch 61/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7057 - loss: 0.5946
# Epoch 62/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6914 - loss: 0.5826
# Epoch 63/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.6055
# Epoch 64/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6888 - loss: 0.5831
# Epoch 65/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7044 - loss: 0.
150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7422 - loss: 0.5197
# Epoch 95/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7552 - loss: 0.5285
# Epoch 96/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7487 - loss: 0.5289
# Epoch 97/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7279 - loss: 0.5337
# Epoch 98/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7565 - loss: 0.5220
# Epoch 99/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7539 - loss: 0.5180
# Epoch 100/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7591 - loss: 0.5067
# Epoch 101/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7487 - loss: 0.5338
# Epoch 102/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7526 - loss: 0.5049
# Epoch 103/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7487 - loss: 0.5208
# Epoch 104/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7539 - loss: 0.5031
# Epoch 105/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7565 - loss: 0.5090
# Epoch 106/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.5226
# Epoch 107/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7695 - loss: 0.5002
# Epoch 108/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7279 - loss: 0.5699
# Epoch 109/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7474 - loss: 0.5558
# Epoch 110/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7526 - loss: 0.5216
# Epoch 111/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7565 - loss: 0.5014
# Epoch 112/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7630 - loss: 0.5010
# Epoch 113/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7591 - loss: 0.5046
# Epoch 114/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7617 - loss: 0.5001
# Epoch 115/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7565 - loss: 0.5181
# Epoch 116/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7487 - loss: 0.5130
# Epoch 117/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.5068
# Epoch 118/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7513 - loss: 0.5104
# Epoch 119/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7487 - loss: 0.5105
# Epoch 120/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 0.5072
# Epoch 121/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7461 - loss: 0.5236
# Epoch 122/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7773 - loss: 0.4988
# Epoch 123/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7474 - loss: 0.5224
# Epoch 124/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7331 - loss: 0.5173
# Epoch 125/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.5063
# Epoch 126/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7630 - loss: 0.5022
# Epoch 127/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7552 - loss: 0.5038
# Epoch 128/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7643 - loss: 0.5164
# Epoch 129/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7591 - loss: 0.5026
# Epoch 130/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7708 - loss: 0.4858
# Epoch 131/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.4962
# Epoch 132/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7734 - loss: 0.5120
# Epoch 133/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7669 - loss: 0.5001
# Epoch 134/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7669 - loss: 0.4836
# Epoch 135/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7448 - loss: 0.5069
# Epoch 136/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7591 - loss: 0.4965
# Epoch 137/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7591 - loss: 0.4905
# Epoch 138/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7526 - loss: 0.5205
# Epoch 139/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.5006
# Epoch 140/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.4819
# Epoch 141/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.4944
# Epoch 142/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7708 - loss: 0.4868
# Epoch 143/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7474 - loss: 0.5130
# Epoch 144/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.5034
# Epoch 145/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7630 - loss: 0.4932
# Epoch 146/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7617 - loss: 0.5117
# Epoch 147/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7474 - loss: 0.5307
# Epoch 148/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7539 - loss: 0.4964
# Epoch 149/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7591 - loss: 0.4944
# Epoch 150/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7565 - loss: 0.4933
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7878 - loss: 0.4660
# Accuracy: 78.78

# %% [markdown]
# #How Does Keras Relate to TensorFlow?
#
# Keras relates to TensorFlow as a high-level neural network API. Keras operates on top of TensorFlow, providing a simplified interface for neural network creation and experimentation. Keras offers user-friendly functions to construct various types of neural networks. TensorFlow provides the underlying computational framework. TensorFlow acts as the engine powering Keras, enabling complex mathematical operations essential for machine learning models. The integration of Keras with TensorFlow allows for efficient model training and deployment. Keras simplifies the model-building process, whereas TensorFlow offers more control and flexibility for customization. Keras is designed for fast prototyping and experimentation, making it ideal for beginners. TensorFlow is suited for fine-tuning and large-scale deployment of models. The synergy between Keras and TensorFlow combines ease of use with powerful computational capabilities.

# %% [markdown]
# #Who Uses Keras?
#
# Keras is used by data scientists, researchers, and developers. Data scientists employ Keras for building and testing machine learning models rapidly. Researchers utilize Keras for conducting experiments with novel algorithms and architectures. Developers use Keras for integrating machine learning functionality into applications and software systems. Keras facilitates easy and quick prototyping, making it a preferred choice for projects requiring fast development cycles. Its user-friendly API, supported by TensorFlow, allows the implementation of complex neural network architectures with minimal coding effort. Keras serves as a bridge for those transitioning from theoretical understanding to practical implementation in the field of machine learning.

# %% [markdown]
# #How to Install Keras?
#
# To install Keras follow the steps mentioned below.
#
# Ensure Python is Installed: Keras requires Python, so verify Python is installed on your system. Use the
# command python --version to check the Python version.
#
# Install Pip: Pip is a package manager for Python. Install it by downloading the get-pip.py file and running python get-pip.py in the command line.
#
# Upgrade Pip (Optional but Recommended): Run pip install --upgrade pip in the command line to ensure you have the latest version of Pip.
#
# Install Keras: With pip ready, install Keras by executing pip install keras in the command line.
# Verify Installation: Confirm Keras is installed correctly by running python -c "import keras; print
# (keras.__version__)". This command should display the installed Keras version.

# %% [markdown]
# #What Are the Core Components of Keras?
# The core components of Keras are listed below.
#
# **Models:** Models in Keras are the fundamental structures for neural network architectures. The two primary types are Sequential and Functional API models. Sequential models allow for the linear stacking of layers, while Functional API models offer flexibility in designing complex architectures.
#
# **Layers:** Layers are the building blocks of Keras models. Layers include densely connected layers, convolutional layers, pooling layers, and more, each providing specific functionality to the neural network.
#
# **Optimizers:** Optimizers determine how the network will be updated based on the loss function. Common optimizers in Keras include SGD, Adam, and RMSprop, each with unique characteristics for training models.
#
# **Loss Functions:** Loss functions measure how well the model performs. Keras provides various loss functions like mean squared error for regression tasks and categorical cross-entropy for classification tasks.
#
# **Metrics:** Metrics in Keras are used to evaluate the performance of models. Examples include accuracy for classification tasks and mean absolute error for regression.

# %% [markdown]
# #What Are the Features of Keras?
#
# The features of Keras are listed below.
#
# **User-Friendly Interface:** Keras provides a simple, consistent interface optimized for common use cases. It offers clear and actionable error messages, facilitating easy development and debugging.
#
# **Modularity:** Keras is modular in nature, allowing users to combine different building blocks like neural layers, cost functions, optimizers, and initialization schemes freely.
#
# **Easy Extensibility:** De8vzel8opers can easily extend Keras to include new modules, making it highly suitable for advanced research and development.
#
# **Python-Based:** Keras runs on top of Python, integrating seamlessly with the Python data science ecosystem. This makes it accessible and convenient for data scientists familiar with Python.
#
# **Multi-Backend Support:** Keras supports multiple backends, including TensorFlow, Theano, and Microsoft Cognitive Toolkit, providing flexibility in choosing the underlying framework.

# %% [markdown]
# #Who Can Benefit from Using Keras?
# Individuals and entities that seek to develop and deploy machine learning models efficiently benefit from using Keras. This includes data scientists, machine learning engineers, and AI researchers who require a high-level neural networks API for building and training models. Keras, with its user-friendly interface, simplifies complex processes, making it ideal for beginners in machine learning. Experienced developers utilize Keras for its flexibility in designing advanced models. Educational institutions and research organizations also find Keras advantageous for teaching and experimenting with deep learning due to its accessibility and strong community support. Businesses leverage Keras for its ability to handle large datasets and integrate with TensorFlow, enabling the creation of scalable, production-ready solutions.

# %% [markdown]
# #What Are the Limitations of Using Keras?
#
# The limitations of using Keras include its focus on high-level functionality, which can restrict detailed customization. Keras prioritizes user-friendliness and simplicity in its design, which sometimes leads to limited low-level API access for complex model modifications. The framework depends heavily on a backend engine, typically TensorFlow, which means Keras inherits any limitations or issues of the underlying backend. This dependency affects performance optimization and flexibility for advanced research purposes. Keras is not the most efficient choice for handling large-scale operations or models with extensive custom layers, as it can result in slower performance compared to lower-level frameworks. Keras obscures the understanding of the underlying operations, making it challenging for users to grasp the intricacies of deep learning models.
